# %% [markdown]
# # Weather Data Analysis using Python (Pandas)
#
# This project performs Exploratory Data Analysis (EDA) on a weather dataset using Python. The dataset contains historical weather information like temperature, wind speed, pressure, humidity, visibility, and weather condition.
#
# ---
#
# ## 🔧 Tools & Libraries Used
# - Python
# - Pandas
#
# ---
#
# ## 🧠 Commands/Functions Used
#
# - `head()` → Shows the first 5 rows of the data
# - `shape` → Returns total number of rows and columns
# - `index` → Displays the index of the dataframe
# - `columns` → Lists all column names
# - `dtypes` → Shows data type of each column
# - `unique()` → Displays unique values (per column)
# - `nunique()` → Total number of unique values (per column)
# - `count()` → Count of non-null values
# - `value_counts()` → Count of each unique value (per column)
# - `info()` → General info about the dataset
#
# ---
#
# ## 📊 Questions Solved in This Project
#
# Each question is answered using Pandas operations step by step:
#
# ### Q1. Find all the unique 'Wind Speed' values in the data.
# ### Q2. Find the number of times when the 'Weather is exactly Clear'.
# ### Q3. Find the number of times when the 'Wind Speed was exactly 4 km/h'.
# ### Q4. Find out all the Null Values in the data.
# ### Q5. Rename the column name 'Weather' to 'Weather Condition'.
# ### Q6. What is the mean 'Visibility'?
# ### Q7. What is the Standard Deviation of 'Pressure'?
# ### Q8. What is the Variance of 'Relative Humidity'?
# ### Q9. Find all instances when 'Snow' was recorded.
# ### Q10. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.
# ### Q11. What is the Min & Max value of each column against each 'Weather Condition'?
# ### Q12. Show all the records where Weather Condition is Fog.
# ### Q13. Find all instances when 'Weather is Clear' or 'Visibility is above 40'.
# ### Q14. Find all instances when:
# A. Weather is Clear and Relative Humidity > 50
# OR
# B. Visibility > 40

# %% [markdown]
# import pand

# %%
data=pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\Jupyter Notebook\Project\1st project  using weather data\Weather2024.csv")

# %%
data
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      01-01-24 0:00    -1.8              -3.9         86                4
# 1      01-01-24 1:00    -1.8              -3.7         87                4
# 2      01-01-24 2:00    -1.8              -3.4         89                7
# 3      01-01-24 3:00    -1.5              -3.2         88                6
# 4      01-01-24 4:00    -1.5              -3.3         88                7
# ...              ...     ...               ...        ...              ...
# 3451  12-12-24 19:00    -4.0              -6.1         85               11
# 3452  12-12-24 20:00    -4.4              -6.4         86                7
# 3453  12-12-24 21:00    -3.9              -5.9         86                6
# 3454  12-12-24 22:00    -3.8              -5.6         87                4
# 3455  12-12-24 23:00    -4.3              -5.8         89                4
#
#       Visibility_km  Press_kPa               Weather
# 0               8.0     101.24                   Fog
# 1               8.0     101.24                   Fog
# 2               4.0     101.26  Freezing Drizzle,Fog
# 3               4.0     101.27  Freezing Drizzle,Fog
# 4               4.8     101.23                   Fog
# ...             ...        ...                   ...
# 3451           12.9     102.30                Cloudy
# 3452           16.1     102.36          Snow Showers
# 3453           16.1     102.37          Snow Showers
# 3454           11.3     102.40          Snow Showers
# 3455           16.1     102.45          Mainly Clear
#
# [3456 rows x 8 columns]

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
# 2  01-01-24 2:00    -1.8              -3.4         89                7
# 3  01-01-24 3:00    -1.5              -3.2         88                6
# 4  01-01-24 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (3456, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=3456, step=1)

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Haze', 'Freezing Drizzle,Haze',
#        'Freezing Rain,Haze', 'Snow,Haze', 'Freezing Fog', 'Snow,Fog',
#        'Freezing Drizzle,Snow', 'Snow,Ice Pellets', 'Rain,Fog', 'Drizzle',
#        'Drizzle,Fog', 'Thunderstorms', 'Thunderstorms,Rain Showers',
#        'Rain Showers,Snow Showers', 'Rain,Snow,Fog', 'Moderate Rain,Fog'],
#       dtype=object)

# %%
data.nunique()
# Out:
# Date/Time           3456
# Temp_C               484
# Dew Point Temp_C     459
# Rel Hum_%             82
# Wind Speed_km/h       29
# Visibility_km         23
# Press_kPa            403
# Weather               31
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           3456
# Temp_C              3456
# Dew Point Temp_C    3456
# Rel Hum_%           3456
# Wind Speed_km/h     3456
# Visibility_km       3456
# Press_kPa           3456
# Weather             3456
# dtype: int64

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mostly Cloudy                 844
# Mainly Clear                  776
# Cloudy                        730
# Clear                         467
# Snow                          164
# Rain                          142
# Rain Showers                   80
# Fog                            60
# Rain,Fog                       59
# Drizzle,Fog                    40
# Snow Showers                   31
# Drizzle                        16
# Freezing Rain                   6
# Snow,Haze                       5
# Freezing Drizzle,Fog            5
# Thunderstorms,Rain Showers      4
# Freezing Drizzle                4
# Freezing Drizzle,Haze           3
# Freezing Rain,Fog               2
# Rain Showers,Snow Showers       2
# Moderate Snow                   2
# Haze                            2
# Freezing Rain,Haze              2
# Snow,Ice Pellets                2
# Snow,Fog                        2
# Rain,Snow                       1
# Freezing Fog                    1
# Freezing Drizzle,Snow           1
# Thunderstorms                   1
# Rain,Snow,Fog                   1
# Moderate Rain,Fog               1
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3456 entries, 0 to 3455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         3456 non-null   object
#  1   Temp_C            3456 non-null   float64
#  2   Dew Point Temp_C  3456 non-null   float64
#  3   Rel Hum_%         3456 non-null   int64
#  4   Wind Speed_km/h   3456 non-null   int64
#  5   Visibility_km     3456 non-null   float64
#  6   Press_kPa         3456 non-null   float64
#  7   Weather           3456 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 216.1+ KB

# %% [markdown]
# ## Q1. Find all the unique 'Wind Speed' values in the data.

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.nunique()
# Out:
# Date/Time           3456
# Temp_C               484
# Dew Point Temp_C     459
# Rel Hum_%             82
# Wind Speed_km/h       29
# Visibility_km         23
# Press_kPa            403
# Weather               31
# dtype: int64

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 29

# %%
data['Wind Speed_km/h'].unique() # Answer
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 41, 50, 57, 63, 46])

# %% [markdown]
# ### Q2. Find the number of times when the 'Weather is exactly Clear'.

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.Weather.value_counts()
# Out:
# Weather
# Mostly Cloudy                 844
# Mainly Clear                  776
# Cloudy                        730
# Clear                         467
# Snow                          164
# Rain                          142
# Rain Showers                   80
# Fog                            60
# Rain,Fog                       59
# Drizzle,Fog                    40
# Snow Showers                   31
# Drizzle                        16
# Freezing Rain                   6
# Snow,Haze                       5
# Freezing Drizzle,Fog            5
# Thunderstorms,Rain Showers      4
# Freezing Drizzle                4
# Freezing Drizzle,Haze           3
# Freezing Rain,Fog               2
# Rain Showers,Snow Showers       2
# Moderate Snow                   2
# Haze                            2
# Freezing Rain,Haze              2
# Snow,Ice Pellets                2
# Snow,Fog                        2
# Rain,Snow                       1
# Freezing Fog                    1
# Freezing Drizzle,Snow           1
# Thunderstorms                   1
# Rain,Snow,Fog                   1
# Moderate Rain,Fog               1
# Name: count, dtype: int64

# %%
data[data.Weather=='Clear']
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-24 19:00   -16.9             -24.8         50               24
# 114   01-05-24 18:00    -7.1             -14.4         56               11
# 115   01-05-24 19:00    -9.2             -15.4         61                7
# 116   01-05-24 20:00    -9.8             -15.7         62                9
# 117   01-05-24 21:00    -9.0             -14.8         63               13
# ...              ...     ...               ...        ...              ...
# 3434   12-12-24 2:00   -10.3             -12.0         87                4
# 3435   12-12-24 3:00    -9.6             -11.3         87                4
# 3436   12-12-24 4:00   -10.1             -11.6         89                6
# 3437   12-12-24 5:00   -10.3             -11.7         89                4
# 3438   12-12-24 6:00    -9.5             -11.3         87                4
#
#       Visibility_km  Press_kPa Weather
# 67             25.0     101.74   Clear
# 114            25.0     100.71   Clear
# 115            25.0     100.80   Clear
# 116            25.0     100.83   Clear
# 117            25.0     100.83   Clear
# ...             ...        ...     ...
# 3434           25.0     101.96   Clear
# 3435           25.0     102.00   Clear
# 3436           25.0     102.04   Clear
# 3437           25.0     102.06   Clear
# 3438           25.0     102.10   Clear
#
# [467 rows x 8 columns]

# %%
data.groupby('Weather').get_group('Clear')
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-24 19:00   -16.9             -24.8         50               24
# 114   01-05-24 18:00    -7.1             -14.4         56               11
# 115   01-05-24 19:00    -9.2             -15.4         61                7
# 116   01-05-24 20:00    -9.8             -15.7         62                9
# 117   01-05-24 21:00    -9.0             -14.8         63               13
# ...              ...     ...               ...        ...              ...
# 3434   12-12-24 2:00   -10.3             -12.0         87                4
# 3435   12-12-24 3:00    -9.6             -11.3         87                4
# 3436   12-12-24 4:00   -10.1             -11.6         89                6
# 3437   12-12-24 5:00   -10.3             -11.7         89                4
# 3438   12-12-24 6:00    -9.5             -11.3         87                4
#
#       Visibility_km  Press_kPa Weather
# 67             25.0     101.74   Clear
# 114            25.0     100.71   Clear
# 115            25.0     100.80   Clear
# 116            25.0     100.83   Clear
# 117            25.0     100.83   Clear
# ...             ...        ...     ...
# 3434           25.0     101.96   Clear
# 3435           25.0     102.00   Clear
# 3436           25.0     102.04   Clear
# 3437           25.0     102.06   Clear
# 3438           25.0     102.10   Clear
#
# [467 rows x 8 columns]

# %% [markdown]
# ## Q3. Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
# 2  01-01-24 2:00    -1.8              -3.4         89                7
# 3  01-01-24 3:00    -1.5              -3.2         88                6
# 4  01-01-24 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data[data['Wind Speed_km/h']== 4]
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      01-01-24 0:00    -1.8              -3.9         86                4
# 1      01-01-24 1:00    -1.8              -3.7         87                4
# 96     01-05-24 0:00    -8.8             -11.7         79                4
# 101    01-05-24 5:00    -7.0              -9.5         82                4
# 146    01-07-24 2:00    -8.1             -11.1         79                4
# ...              ...     ...               ...        ...              ...
# 3439   12-12-24 7:00   -11.2             -12.4         91                4
# 3441   12-12-24 9:00    -6.1              -9.0         80                4
# 3448  12-12-24 16:00    -2.8              -6.2         77                4
# 3454  12-12-24 22:00    -3.8              -5.6         87                4
# 3455  12-12-24 23:00    -4.3              -5.8         89                4
#
#       Visibility_km  Press_kPa        Weather
# 0               8.0     101.24            Fog
# 1               8.0     101.24            Fog
# 96              9.7     100.32           Snow
# 101             4.0     100.19           Snow
# 146            19.3     100.15         Cloudy
# ...             ...        ...            ...
# 3439           24.1     102.19   Mainly Clear
# 3441           24.1     102.21   Snow Showers
# 3448           12.9     102.20  Mostly Cloudy
# 3454           11.3     102.40   Snow Showers
# 3455           16.1     102.45   Mainly Clear
#
# [167 rows x 8 columns]

# %% [markdown]
# ## Q4. Find out all the Null Values in the data.

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           3456
# Temp_C              3456
# Dew Point Temp_C    3456
# Rel Hum_%           3456
# Wind Speed_km/h     3456
# Visibility_km       3456
# Press_kPa           3456
# Weather             3456
# dtype: int64

# %% [markdown]
# ## Q5. Rename the column name 'Weather' to 'Weather Condition'.

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
# 2  01-01-24 2:00    -1.8              -3.4         89                7
# 3  01-01-24 3:00    -1.5              -3.2         88                6
# 4  01-01-24 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.rename(columns = {'Weather' : 'Weather condition'},inplace=True)

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
# 2  01-01-24 2:00    -1.8              -3.4         89                7
# 3  01-01-24 3:00    -1.5              -3.2         88                6
# 4  01-01-24 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# ## Q6. What is the mean 'Visibility'?

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
# 2  01-01-24 2:00    -1.8              -3.4         89                7
# 3  01-01-24 3:00    -1.5              -3.2         88                6
# 4  01-01-24 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.Visibility_km.mean()
# Out:
# np.float64(27.596701388888892)

# %% [markdown]
# ## Q7. What is the Standard Deviation of 'Pressure'?

# %%
data.Press_kPa.std()
# Out:
# 0.7524035243580811

# %% [markdown]
# ## Q8. What is the Variance of 'Relative Humidity'?

# %%
data['Rel Hum_%'].var()
# Out:
# 293.49062876869385

# %% [markdown]
# ## Q9. Find all instances when 'Snow' was recorded.

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
# 2  01-01-24 2:00    -1.8              -3.4         89                7
# 3  01-01-24 3:00    -1.5              -3.2         88                6
# 4  01-01-24 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data['Weather condition'].value_counts()
# Out:
# Weather condition
# Mostly Cloudy                 844
# Mainly Clear                  776
# Cloudy                        730
# Clear                         467
# Snow                          164
# Rain                          142
# Rain Showers                   80
# Fog                            60
# Rain,Fog                       59
# Drizzle,Fog                    40
# Snow Showers                   31
# Drizzle                        16
# Freezing Rain                   6
# Snow,Haze                       5
# Freezing Drizzle,Fog            5
# Thunderstorms,Rain Showers      4
# Freezing Drizzle                4
# Freezing Drizzle,Haze           3
# Freezing Rain,Fog               2
# Rain Showers,Snow Showers       2
# Moderate Snow                   2
# Haze                            2
# Freezing Rain,Haze              2
# Snow,Ice Pellets                2
# Snow,Fog                        2
# Rain,Snow                       1
# Freezing Fog                    1
# Freezing Drizzle,Snow           1
# Thunderstorms                   1
# Rain,Snow,Fog                   1
# Moderate Rain,Fog               1
# Name: count, dtype: int64

# %%
data[data['Weather condition']== 'Snow']
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55     01-03-24 7:00   -14.0             -19.5         63               19
# 84    01-04-24 12:00   -13.7             -21.7         51               11
# 86    01-04-24 14:00   -11.3             -19.0         53                7
# 87    01-04-24 15:00   -10.2             -16.3         61               11
# 88    01-04-24 16:00    -9.4             -15.5         61               13
# ...              ...     ...               ...        ...              ...
# 3283  12-05-24 19:00    -1.0              -8.5         57               28
# 3335  12-07-24 23:00     1.5              -2.2         76                4
# 3336   12-08-24 0:00     1.8              -1.4         79                4
# 3385   12-10-24 1:00    -5.0              -6.2         91               32
# 3386   12-10-24 2:00    -4.7              -6.2         89               33
#
#       Visibility_km  Press_kPa Weather condition
# 55             25.0     100.95              Snow
# 84             24.1     101.25              Snow
# 86             19.3     100.97              Snow
# 87              9.7     100.89              Snow
# 88             19.3     100.79              Snow
# ...             ...        ...               ...
# 3283           25.0     101.84              Snow
# 3335           19.3     101.22              Snow
# 3336           25.0     101.20              Snow
# 3385            1.6     101.31              Snow
# 3386            4.0     101.10              Snow
#
# [164 rows x 8 columns]

# %%
data[data['Weather condition'].str.contains('Snow')].head(50)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   01-02-24 17:00    -2.1              -9.5         57               22
# 44   01-02-24 20:00    -5.6             -13.4         54               24
# 45   01-02-24 21:00    -5.8             -12.8         58               26
# 47   01-02-24 23:00    -7.4             -14.1         59               17
# 48    01-03-24 0:00    -9.0             -16.0         57               28
# 50    01-03-24 2:00   -10.5             -15.8         65               22
# 51    01-03-24 3:00   -11.3             -18.7         54               33
# 53    01-03-24 5:00   -12.9             -19.1         60               22
# 54    01-03-24 6:00   -13.3             -19.3         61               19
# 55    01-03-24 7:00   -14.0             -19.5         63               19
# 84   01-04-24 12:00   -13.7             -21.7         51               11
# 86   01-04-24 14:00   -11.3             -19.0         53                7
# 87   01-04-24 15:00   -10.2             -16.3         61               11
# 88   01-04-24 16:00    -9.4             -15.5         61               13
# 89   01-04-24 17:00    -8.9             -13.2         71                9
# 90   01-04-24 18:00    -8.9             -12.6         75               11
# 91   01-04-24 19:00    -8.4             -12.7         71                9
# 92   01-04-24 20:00    -7.8             -12.1         71                9
# 93   01-04-24 21:00    -7.6             -11.6         73                7
# 94   01-04-24 22:00    -9.5             -12.7         77                6
# 95   01-04-24 23:00    -9.6             -12.6         79                6
# 96    01-05-24 0:00    -8.8             -11.7         79                4
# 97    01-05-24 1:00    -7.5             -10.2         81                0
# 98    01-05-24 2:00    -5.4              -8.3         80                9
# 99    01-05-24 3:00    -5.0              -7.7         81               11
# 100   01-05-24 4:00    -4.1              -6.5         83                9
# 101   01-05-24 5:00    -7.0              -9.5         82                4
# 102   01-05-24 6:00    -8.2             -10.7         82                6
# 103   01-05-24 7:00    -7.1              -9.7         82                9
# 104   01-05-24 8:00    -6.1              -9.1         79               11
# 123   01-06-24 3:00   -10.6             -16.0         64                0
# 124   01-06-24 4:00   -11.3             -16.1         68               15
# 125   01-06-24 5:00   -11.8             -16.0         71               19
# 126   01-06-24 6:00   -12.0             -16.2         71               22
# 127   01-06-24 7:00   -14.4             -16.3         85               22
# 128   01-06-24 8:00   -12.3             -16.2         73               24
# 129   01-06-24 9:00   -12.5             -16.7         71               26
# 130  01-06-24 10:00   -12.3             -16.3         72               28
# 131  01-06-24 11:00   -12.0             -16.0         72               17
# 132  01-06-24 12:00   -11.7             -15.4         74               28
# 133  01-06-24 13:00   -11.9             -15.6         74               20
# 134  01-06-24 14:00   -11.2             -14.8         75               19
# 135  01-06-24 15:00   -11.5             -14.4         79               19
# 136  01-06-24 16:00   -11.6             -14.7         78               19
# 137  01-06-24 17:00   -11.2             -14.3         78               17
# 158  01-07-24 14:00    -4.4              -6.9         83                6
# 159  01-07-24 15:00    -3.7              -6.1         83               11
# 160  01-07-24 16:00    -3.6              -5.9         84                0
# 161  01-07-24 17:00    -3.1              -5.4         84               13
# 162  01-07-24 18:00    -3.2              -5.3         85                6
#
#      Visibility_km  Press_kPa Weather condition
# 41            25.0      99.66      Snow Showers
# 44            25.0     100.07      Snow Showers
# 45            25.0     100.15      Snow Showers
# 47            19.3     100.27      Snow Showers
# 48            25.0     100.35      Snow Showers
# 50            12.9     100.53      Snow Showers
# 51            25.0     100.61      Snow Showers
# 53            25.0     100.76      Snow Showers
# 54            25.0     100.85      Snow Showers
# 55            25.0     100.95              Snow
# 84            24.1     101.25              Snow
# 86            19.3     100.97              Snow
# 87             9.7     100.89              Snow
# 88            19.3     100.79              Snow
# 89             4.8     100.76              Snow
# 90             9.7     100.69              Snow
# 91            16.1     100.65              Snow
# 92            16.1     100.61              Snow
# 93            11.3     100.54              Snow
# 94             9.7     100.50              Snow
# 95             9.7     100.42              Snow
# 96             9.7     100.32              Snow
# 97             9.7     100.29              Snow
# 98             8.0     100.28              Snow
# 99             9.7     100.24              Snow
# 100            4.8     100.21              Snow
# 101            4.0     100.19              Snow
# 102            6.4     100.26              Snow
# 103            9.7     100.31              Snow
# 104            9.7     100.39              Snow
# 123            9.7     100.76              Snow
# 124            3.2     100.70              Snow
# 125            2.8     100.61              Snow
# 126            4.8     100.58              Snow
# 127            2.4     100.52              Snow
# 128           11.3     100.51              Snow
# 129           19.3     100.53              Snow
# 130           16.1     100.47              Snow
# 131           24.1     100.36              Snow
# 132           19.3     100.23              Snow
# 133           24.1     100.13              Snow
# 134           19.3     100.07              Snow
# 135           12.9     100.06              Snow
# 136           19.3     100.10              Snow
# 137           25.0     100.15              Snow
# 158            8.0     100.09              Snow
# 159            8.0     100.09              Snow
# 160            8.0     100.15              Snow
# 161            8.0     100.27              Snow
# 162            9.7     100.33              Snow

# %% [markdown]
# ## Q10. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Wind Speed_km/h']>24)&(data['Visibility_km'] == 25)]
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23    01-01-24 23:00     5.3               2.0         79               30
# 24     01-02-24 0:00     5.2               1.5         77               35
# 25     01-02-24 1:00     4.6               0.0         72               39
# 26     01-02-24 2:00     3.9              -0.9         71               32
# 27     01-02-24 3:00     3.7              -1.5         69               33
# ...              ...     ...               ...        ...              ...
# 3286  12-05-24 22:00    -1.6              -9.5         55               26
# 3380  12-09-24 20:00    -2.2              -7.2         69               28
# 3382  12-09-24 22:00    -3.0              -8.2         67               28
# 3383  12-09-24 23:00    -3.6              -8.6         68               32
# 3409   12-11-24 1:00     0.0              -3.6         77               28
#
#       Visibility_km  Press_kPa Weather condition
# 23             25.0      99.31            Cloudy
# 24             25.0      99.26      Rain Showers
# 25             25.0      99.26            Cloudy
# 26             25.0      99.26     Mostly Cloudy
# 27             25.0      99.30     Mostly Cloudy
# ...             ...        ...               ...
# 3286           25.0     102.01     Mostly Cloudy
# 3380           25.0     102.11            Cloudy
# 3382           25.0     101.78            Cloudy
# 3383           25.0     101.64            Cloudy
# 3409           25.0      99.99            Cloudy
#
# [119 rows x 8 columns]

# %% [markdown]
# ### Q11. What is the Min & Max value of each column against each 'Weather Condition'?

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
# 2  01-01-24 2:00    -1.8              -3.4         89                7
# 3  01-01-24 3:00    -1.5              -3.2         88                6
# 4  01-01-24 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.groupby('Weather condition').min()
# Out:
#                                  Date/Time  Temp_C  Dew Point Temp_C  \
# Weather condition
# Clear                       01-03-24 19:00   -16.9             -24.8
# Cloudy                      01-01-24 17:00   -18.5             -24.1
# Drizzle                     05-01-24 15:00     4.2               2.0
# Drizzle,Fog                 05-01-24 16:00     0.0              -0.5
# Fog                          01-01-24 0:00   -11.2             -13.2
# Freezing Drizzle            01-07-24 11:00    -6.8              -9.3
# Freezing Drizzle,Fog         01-01-24 2:00    -6.4              -9.0
# Freezing Drizzle,Haze       02-01-24 11:00    -5.8              -8.3
# Freezing Drizzle,Snow       03-02-24 12:00    -5.2              -7.1
# Freezing Fog                02-05-24 10:00   -11.1             -13.4
# Freezing Rain               01-07-24 10:00    -6.5              -9.0
# Freezing Rain,Fog            01-07-24 9:00    -6.1              -8.7
# Freezing Rain,Haze          02-01-24 14:00    -4.9              -7.5
# Haze                        02-01-24 10:00    -5.7              -8.5
# Mainly Clear                01-02-24 12:00   -18.6             -25.4
# Moderate Rain,Fog            12-10-24 8:00     1.7               0.8
# Moderate Snow               01-12-24 15:00    -5.2              -7.6
# Mostly Cloudy               01-01-24 16:00   -17.8             -25.1
# Rain                        01-01-24 18:00     0.3              -4.0
# Rain Showers                01-01-24 22:00     1.7              -1.0
# Rain Showers,Snow Showers    11-04-24 8:00     2.1              -1.8
# Rain,Fog                    03-08-24 22:00     0.0              -0.5
# Rain,Snow                    01-10-24 5:00     0.8              -1.2
# Rain,Snow,Fog               12-08-24 21:00     0.8               0.3
# Snow                         01-03-24 7:00   -16.7             -24.6
# Snow Showers                01-02-24 17:00   -13.3             -19.3
# Snow,Fog                    02-10-24 23:00    -1.4              -2.4
# Snow,Haze                   02-01-24 17:00    -4.3              -7.2
# Snow,Ice Pellets             03-03-24 4:00    -4.3              -5.9
# Thunderstorms               07-04-24 16:00    26.7              20.1
# Thunderstorms,Rain Showers  07-04-24 17:00    20.2              15.8
#
#                             Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# Weather condition
# Clear                              20                0           12.9
# Cloudy                             27                0           11.3
# Drizzle                            79                4            6.4
# Drizzle,Fog                        87                0            1.0
# Fog                                85                0            0.4
# Freezing Drizzle                   81                9            4.8
# Freezing Drizzle,Fog               82                6            3.6
# Freezing Drizzle,Haze              81                9            2.0
# Freezing Drizzle,Snow              86               13            2.4
# Freezing Fog                       83                9            0.8
# Freezing Rain                      81                7            4.8
# Freezing Rain,Fog                  82                7            8.0
# Freezing Rain,Haze                 82                6            2.0
# Haze                               81                0            4.8
# Mainly Clear                       20                0           12.9
# Moderate Rain,Fog                  94               17            6.4
# Moderate Snow                      83               26            0.6
# Mostly Cloudy                      18                0           12.9
# Rain                               40                0            4.0
# Rain Showers                       40                0            6.4
# Rain Showers,Snow Showers          75               17           19.3
# Rain,Fog                           83                0            2.4
# Rain,Snow                          86               30            9.7
# Rain,Snow,Fog                      96                9            6.4
# Snow                               50                0            1.0
# Snow Showers                       54                4            9.7
# Snow,Fog                           90                6            6.4
# Snow,Haze                          80                0            4.0
# Snow,Ice Pellets                   86               24            2.8
# Thunderstorms                      67               15           24.1
# Thunderstorms,Rain Showers         68               11           12.9
#
#                             Press_kPa
# Weather condition
# Clear                          100.31
# Cloudy                          98.70
# Drizzle                         99.22
# Drizzle,Fog                     99.34
# Fog                            100.07
# Freezing Drizzle               100.05
# Freezing Drizzle,Fog           100.10
# Freezing Drizzle,Haze          100.28
# Freezing Drizzle,Snow          101.18
# Freezing Fog                   101.97
# Freezing Rain                  100.07
# Freezing Rain,Fog              100.15
# Freezing Rain,Haze             100.34
# Haze                           100.35
# Mainly Clear                    98.67
# Moderate Rain,Fog               99.98
# Moderate Snow                   99.88
# Mostly Cloudy                   98.67
# Rain                            99.05
# Rain Showers                    98.82
# Rain Showers,Snow Showers      101.09
# Rain,Fog                        99.32
# Rain,Snow                      100.02
# Rain,Snow,Fog                  100.73
# Snow                            98.98
# Snow Showers                    99.66
# Snow,Fog                       100.76
# Snow,Haze                      100.61
# Snow,Ice Pellets                99.40
# Thunderstorms                   99.84
# Thunderstorms,Rain Showers      99.85

# %%
data.groupby('Weather condition').max()
# Out:
#                                  Date/Time  Temp_C  Dew Point Temp_C  \
# Weather condition
# Clear                        12-12-24 6:00    32.8              19.8
# Cloudy                      12-12-24 19:00    30.5              22.6
# Drizzle                     11-03-24 19:00    14.7              14.1
# Drizzle,Fog                 12-10-24 15:00    14.4              13.2
# Fog                          12-09-24 0:00    20.8              18.8
# Freezing Drizzle             02-01-24 5:00    -5.4              -7.7
# Freezing Drizzle,Fog         12-10-24 5:00    -1.5              -2.8
# Freezing Drizzle,Haze       02-01-24 13:00    -5.0              -7.7
# Freezing Drizzle,Snow       03-02-24 12:00    -5.2              -7.1
# Freezing Fog                02-05-24 10:00   -11.1             -13.4
# Freezing Rain                02-01-24 7:00    -4.8              -7.2
# Freezing Rain,Fog            12-10-24 6:00     0.1              -0.9
# Freezing Rain,Haze          02-01-24 15:00    -4.9              -7.4
# Haze                        02-01-24 16:00    -4.5              -7.2
# Mainly Clear                 12-12-24 7:00    30.8              21.2
# Moderate Rain,Fog            12-10-24 8:00     1.7               0.8
# Moderate Snow               01-12-24 16:00    -4.9              -7.3
# Mostly Cloudy                12-12-24 8:00    32.2              24.4
# Rain                         12-05-24 3:00    22.3              19.9
# Rain Showers                 12-04-24 9:00    26.3              23.0
# Rain Showers,Snow Showers   12-05-24 10:00     2.2              -1.2
# Rain,Fog                     12-10-24 9:00    21.7              19.5
# Rain,Snow                    01-10-24 5:00     0.8              -1.2
# Rain,Snow,Fog               12-08-24 21:00     0.8               0.3
# Snow                         12-10-24 2:00     2.9              -0.7
# Snow Showers                 12-12-24 9:00     2.9              -1.2
# Snow,Fog                     02-11-24 0:00    -0.9              -2.3
# Snow,Haze                   02-01-24 21:00    -3.6              -6.4
# Snow,Ice Pellets             12-10-24 3:00     0.3              -1.7
# Thunderstorms               07-04-24 16:00    26.7              20.1
# Thunderstorms,Rain Showers   09-08-24 4:00    25.0              22.0
#
#                             Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# Weather condition
# Clear                              99               32           48.3
# Cloudy                             99               41           48.3
# Drizzle                            96               24           25.0
# Drizzle,Fog                       100               19            9.7
# Fog                               100               22            9.7
# Freezing Drizzle                   84               19            9.7
# Freezing Drizzle,Fog               94               33            8.0
# Freezing Drizzle,Haze              83               11            4.0
# Freezing Drizzle,Snow              86               13            2.4
# Freezing Fog                       83                9            0.8
# Freezing Rain                      84               17            9.7
# Freezing Rain,Fog                  93               22            9.7
# Freezing Rain,Haze                 83                9            2.8
# Haze                               81               13            8.0
# Mainly Clear                       99               63           48.3
# Moderate Rain,Fog                  94               17            6.4
# Moderate Snow                      83               33            0.8
# Mostly Cloudy                     100               57           48.3
# Rain                               97               46           25.0
# Rain Showers                       97               39           48.3
# Rain Showers,Snow Showers          78               28           24.1
# Rain,Fog                           99               46            9.7
# Rain,Snow                          86               30            9.7
# Rain,Snow,Fog                      96                9            6.4
# Snow                               91               57           25.0
# Snow Showers                       87               33           25.0
# Snow,Fog                           94                9            9.7
# Snow,Haze                          81               15            6.4
# Snow,Ice Pellets                   89               33           11.3
# Thunderstorms                      67               15           24.1
# Thunderstorms,Rain Showers         96               32           25.0
#
#                             Press_kPa
# Weather condition
# Clear                          103.26
# Cloudy                         103.19
# Drizzle                        101.56
# Drizzle,Fog                    101.70
# Fog                            102.47
# Freezing Drizzle               100.61
# Freezing Drizzle,Fog           101.27
# Freezing Drizzle,Haze          100.36
# Freezing Drizzle,Snow          101.18
# Freezing Fog                   101.97
# Freezing Rain                  100.56
# Freezing Rain,Fog              100.30
# Freezing Rain,Haze             100.41
# Haze                           100.47
# Mainly Clear                   103.27
# Moderate Rain,Fog               99.98
# Moderate Snow                   99.90
# Mostly Cloudy                  103.23
# Rain                           102.26
# Rain Showers                   102.31
# Rain Showers,Snow Showers      101.11
# Rain,Fog                       101.30
# Rain,Snow                      100.02
# Rain,Snow,Fog                  100.73
# Snow                           102.73
# Snow Showers                   102.50
# Snow,Fog                       100.78
# Snow,Haze                      100.99
# Snow,Ice Pellets               100.96
# Thunderstorms                   99.84
# Thunderstorms,Rain Showers     100.58

# %% [markdown]
# ### Q12. Show all the records where Weather Condition is Fog.

# %%
data[data['Weather condition']=='Fog']
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0      01-01-24 0:00    -1.8              -3.9         86                4
# 1      01-01-24 1:00    -1.8              -3.7         87                4
# 4      01-01-24 4:00    -1.5              -3.3         88                7
# 5      01-01-24 5:00    -1.4              -3.3         87                9
# 6      01-01-24 6:00    -1.5              -3.1         89                7
# 7      01-01-24 7:00    -1.4              -3.6         85                7
# 8      01-01-24 8:00    -1.4              -3.6         85                9
# 9      01-01-24 9:00    -1.3              -3.1         88               15
# 10    01-01-24 10:00    -1.0              -2.3         91                9
# 11    01-01-24 11:00    -0.5              -2.1         89                7
# 12    01-01-24 12:00    -0.2              -2.0         88                9
# 13    01-01-24 13:00     0.2              -1.7         87               13
# 14    01-01-24 14:00     0.8              -1.1         87               20
# 15    01-01-24 15:00     1.8              -0.4         85               22
# 166   01-07-24 22:00    -1.5              -3.0         89                4
# 341    02-03-24 5:00   -11.2             -13.2         85                9
# 614   03-02-24 14:00    -4.1              -6.1         86               15
# 889    04-02-24 1:00    -0.1              -1.4         91                7
# 891    04-02-24 3:00    -1.4              -2.8         90                0
# 892    04-02-24 4:00    -1.2              -2.2         93                4
# 1161   05-01-24 9:00     8.4               6.8         90               13
# 1177   05-02-24 1:00     8.6               7.8         95                6
# 1178   05-02-24 2:00     8.8               7.7         93                4
# 1179   05-02-24 3:00     8.8               7.7         93                4
# 1180   05-02-24 4:00     8.6               7.5         93                9
# 1181   05-02-24 5:00     8.4               7.3         93               13
# 1182   05-02-24 6:00     8.6               7.5         93               11
# 1184   05-02-24 8:00     8.4               7.2         92               15
# 1185   05-02-24 9:00     8.9               7.4         90               13
# 1186  05-02-24 10:00     9.5               7.8         89               13
# 1229   05-04-24 5:00    13.2              11.2         88                6
# 1339  05-08-24 19:00    12.3              10.5         89                6
# 1341  05-08-24 21:00    12.2              10.6         90                6
# 1342  05-08-24 22:00    12.3              10.7         90                6
# 1351   05-09-24 7:00    14.3              12.5         89               15
# 1352   05-09-24 8:00    14.3              12.3         88               17
# 2243  08-10-24 11:00    19.9              18.5         92               15
# 2244  08-10-24 12:00    20.8              18.8         88               17
# 2284   08-12-24 4:00    19.5              18.8         96                4
# 2285   08-12-24 5:00    19.6              18.7         95                4
# 2645   10-03-24 5:00    11.0              11.0        100               11
# 2646   10-03-24 6:00    11.5              11.5        100               11
# 2647   10-03-24 7:00    11.7              11.7        100               13
# 2648   10-03-24 8:00    11.4              11.4        100               15
# 2649   10-03-24 9:00    12.7              12.6         99               19
# 2650  10-03-24 10:00    14.8              13.5         92               19
# 2670   10-04-24 6:00    11.3              10.8         97                9
# 2672   10-04-24 8:00    12.0              11.8         99                7
# 2675  10-04-24 11:00    13.3              12.8         97                6
# 2679  10-04-24 15:00    15.9              14.7         93                4
# 2680  10-04-24 16:00    16.0              15.5         97                4
# 2681  10-04-24 17:00    15.8              15.3         97                4
# 2682  10-04-24 18:00    14.6              14.5         99                0
# 2683  10-04-24 19:00    14.8              14.6         99                6
# 2684  10-04-24 20:00    14.1              14.1        100                4
# 2685  10-04-24 21:00    14.4              13.7         96                6
# 3213  12-02-24 21:00     6.7               6.6         99               11
# 3343   12-08-24 7:00     2.3               1.0         91                6
# 3358  12-08-24 22:00     1.2               0.6         96               13
# 3360   12-09-24 0:00     1.5               0.7         94               20
#
#       Visibility_km  Press_kPa Weather condition
# 0               8.0     101.24               Fog
# 1               8.0     101.24               Fog
# 4               4.8     101.23               Fog
# 5               6.4     101.27               Fog
# 6               6.4     101.29               Fog
# 7               8.0     101.26               Fog
# 8               8.0     101.23               Fog
# 9               4.0     101.20               Fog
# 10              1.2     101.15               Fog
# 11              4.0     100.98               Fog
# 12              4.8     100.79               Fog
# 13              4.8     100.58               Fog
# 14              4.8     100.31               Fog
# 15              6.4     100.07               Fog
# 166             4.0     100.54               Fog
# 341             9.7     102.47               Fog
# 614             8.0     101.03               Fog
# 889             9.7     100.27               Fog
# 891             8.0     100.33               Fog
# 892             9.7     100.38               Fog
# 1161            9.7     101.09               Fog
# 1177            0.6     101.44               Fog
# 1178            0.4     101.44               Fog
# 1179            0.4     101.49               Fog
# 1180            1.2     101.52               Fog
# 1181            1.0     101.57               Fog
# 1182            1.6     101.58               Fog
# 1184            2.4     101.71               Fog
# 1185            6.4     101.68               Fog
# 1186            6.4     101.73               Fog
# 1229            8.0     100.67               Fog
# 1339            8.0     100.30               Fog
# 1341            8.0     100.31               Fog
# 1342            8.0     100.30               Fog
# 1351            4.8     100.12               Fog
# 1352            6.4     100.12               Fog
# 2243            6.4     100.73               Fog
# 2244            6.4     100.73               Fog
# 2284            9.7     100.68               Fog
# 2285            8.0     100.75               Fog
# 2645            3.2     101.38               Fog
# 2646            0.6     101.42               Fog
# 2647            0.6     101.49               Fog
# 2648            1.6     101.54               Fog
# 2649            4.8     101.53               Fog
# 2650            9.7     101.50               Fog
# 2670            6.4     101.58               Fog
# 2672            4.0     101.57               Fog
# 2675            6.4     101.47               Fog
# 2679            9.7     101.24               Fog
# 2680            9.7     101.18               Fog
# 2681            9.7     101.13               Fog
# 2682            9.7     101.12               Fog
# 2683            9.7     101.10               Fog
# 2684            9.7     101.10               Fog
# 2685            9.7     101.07               Fog
# 3213            8.0     100.70               Fog
# 3343            8.0     101.09               Fog
# 3358            6.4     100.84               Fog
# 3360            9.7     101.07               Fog

# %% [markdown]
# ### Q13. Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
data[(data['Weather condition']=='Clear') | (data['Visibility_km'] > 40)]
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-24 19:00   -16.9             -24.8         50               24
# 106   01-05-24 10:00    -6.0             -10.0         73               17
# 107   01-05-24 11:00    -5.6             -10.2         70               22
# 108   01-05-24 12:00    -4.7              -9.6         69               20
# 109   01-05-24 13:00    -4.4              -9.7         66               26
# ...              ...     ...               ...        ...              ...
# 3434   12-12-24 2:00   -10.3             -12.0         87                4
# 3435   12-12-24 3:00    -9.6             -11.3         87                4
# 3436   12-12-24 4:00   -10.1             -11.6         89                6
# 3437   12-12-24 5:00   -10.3             -11.7         89                4
# 3438   12-12-24 6:00    -9.5             -11.3         87                4
#
#       Visibility_km  Press_kPa Weather condition
# 67             25.0     101.74             Clear
# 106            48.3     100.45      Mainly Clear
# 107            48.3     100.41      Mainly Clear
# 108            48.3     100.38      Mainly Clear
# 109            48.3     100.40      Mainly Clear
# ...             ...        ...               ...
# 3434           25.0     101.96             Clear
# 3435           25.0     102.00             Clear
# 3436           25.0     102.04             Clear
# 3437           25.0     102.06             Clear
# 3438           25.0     102.10             Clear
#
# [1113 rows x 8 columns]

# %% [markdown]
# ### Q14. Find all instances when:
# A. Weather is Clear and Relative Humidity > 50
# OR
# B. Visibility > 40

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-24 0:00    -1.8              -3.9         86                4
# 1  01-01-24 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Weather condition']=='Clear') & (data['Rel Hum_%']>50) | (data['Visibility_km']>40)]
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106   01-05-24 10:00    -6.0             -10.0         73               17
# 107   01-05-24 11:00    -5.6             -10.2         70               22
# 108   01-05-24 12:00    -4.7              -9.6         69               20
# 109   01-05-24 13:00    -4.4              -9.7         66               26
# 110   01-05-24 14:00    -5.1             -10.7         65               22
# ...              ...     ...               ...        ...              ...
# 3434   12-12-24 2:00   -10.3             -12.0         87                4
# 3435   12-12-24 3:00    -9.6             -11.3         87                4
# 3436   12-12-24 4:00   -10.1             -11.6         89                6
# 3437   12-12-24 5:00   -10.3             -11.7         89                4
# 3438   12-12-24 6:00    -9.5             -11.3         87                4
#
#       Visibility_km  Press_kPa Weather condition
# 106            48.3     100.45      Mainly Clear
# 107            48.3     100.41      Mainly Clear
# 108            48.3     100.38      Mainly Clear
# 109            48.3     100.40      Mainly Clear
# 110            48.3     100.46      Mainly Clear
# ...             ...        ...               ...
# 3434           25.0     101.96             Clear
# 3435           25.0     102.00             Clear
# 3436           25.0     102.04             Clear
# 3437           25.0     102.06             Clear
# 3438           25.0     102.10             Clear
#
# [1062 rows x 8 columns]
